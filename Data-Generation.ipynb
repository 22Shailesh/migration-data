# %% [markdown]
# ## A Random Person

# %%
import json as json
import random as random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from generator.person import *

# %%
with open("input/world/world.json", 'r') as f1:
    world = json.load(f1)

# %%
with open("input/nepal/NepalG.json", 'r') as f2:
    nepal = json.load(f2)

# %%
with open("input/professions/profession.json", 'r') as f3:
    prof = json.load(f3)

# %%
with open("input/views/views.json", 'r') as f4:
    views = json.load(f4)

# %%
with open("input/interest/personal.json", 'r') as f5:
    personal = json.load(f5)

# %%
with open("input/interest/interest.json", 'r') as f6:
    interest = json.load(f6)

# %%
with open("input/interest/socialwork.json", 'r') as f7:
    socialwork = json.load(f7)

# %%
Data = []
for k in range(1000):
    P = Person()
    P.set_ID()
    P.set_age()
    P.set_home_address(nepal)
    P.set_foreign_address(world)
    P.set_profession(prof) 
    P.set_date_out()
    P.set_date_return()
    P.set_fund2invest(interest)
    P.set_personal_view(views)
    P.set_gender()
    P.set_interest(personal)
    P.set_remittance()
    P.set_travell(world)
    P.set_social_work(socialwork)

    Data.append({"ID": P.ID,\
                 "age" : P.age,\
                 "gender" : P.gender,\
                 "profession": P.profession,\
                 "interest": P.interest,\
                 "home_address" : P.home_address,\
                 "foreign_address": P.foreign_address,\
                 "date_out": P.date_out,\
                 "date_return":P.date_return,\
                 "fund2invest":P.fund2invest,\
                 "remittance":P.remittance,\
                 "travell":P.travell,\
                 "social_work":P.social_work,\
                 "personal_view":P.personal_view})

# %%
Data[0:10]
# Out:
# [{'ID': '82Q6H2OCLB',
#   'age': 42,
#   'gender': 'male',
#   'profession': {'major': 'Arts, Design, Entertainment, Sports, and Media Occupations',
#    'branch': 'Interior Designers'},
#   'interest': 'stories',
#   'home_address': {'province': 'PN1',
#    'district': 'Panchthar',
#    'MCP': 'Miklajung RM',
#    'ward': 'Ward 6'},
#   'foreign_address': {'country': 'Aruba',
#    'ID': 'AW',
#    'lat': '12.52111',
#    'lon': '-69.968338',
#    'city': 'ORANJESTAD'},
#   'date_out': '2015.2.12',
#   'date_return': '2019.3.9',
#   'fund2invest': {'invetsment sector': '8%',
#    'tourism and hospitality': '2%',
#    'animal husbandary': '6%',
#    'infrastructure': '8%',
#    'cottage industries': '6%',
#    'personal service business': '10%',
#    'retail business': '4%',
#    'consultancy service': '2%',
#    'alternative energy': '6%',
#    'agriculture': '8%',
#    'total_fund': 7109},
#   'remittance': [{'month': 6, 'amount': 459},
#    {'month': 3, 'amount': 466},
#    {'month': 3, 'amount': 794},
#    {'month': 8, 'amount': 400}],
#   'travell': [{'date': '2017.11.7',
#     'place': {'country': 'Lithuania', 'city': 'Panevezhis'}},
#    {'date': '2015.1.26',
#     'place': {'country': 'Papua-New-Guinea', 'city': 'N'}},
#    {'date': '2019.7.5',
#     'place': {'country': 'Macedonia-[FYROM]', 'city': 'A'}}],
#   'social_work': [{'date': '2002.7.6', 'work': 'pollution control'},
#    {'date': '2012.1.15', 'work': 'workshop for young'}],
#   'personal_view': ['While all parties involved in the construction process have contributed to the current fiasco, one lesson is especially poignant as stakeholders take the next necessary steps to identify a new contractor: more thoughtful deliberation must factor into procurement decisions. A number of factors—including corruption, mismanagement, deviation from contract promises, sluggish cash flow, and a circular bout of finger pointing—has played into the current Melamchi saga. But tussles between contractors and government officials, often manifesting in contract terminations, have featured heavily in these delays.']},
#  {'ID': '53OHV7F4E3',
#   'age': 42,
#   'gender': 'female',
#   'profession': {'major': 'Sales and Related Occupations',
#    'branch': 'Telemarketers'},
#   'interest': 'movies',
#   'home_address': {'province': 'PN3',
#    'district': 'Chitwan',
#    'MCP': 'Ichchhakamana RM',
#    'ward': 'Ward 6'},
#   'foreign_address': {'country': 'Senegal',
#    'ID': 'SN',
#    'lat': '14.497401',
#    'lon': '-14.452362',
#    'city': 'Rufisque'},
#   'date_out': '2017.8.11',
#   'date_return': '2022.7.30',
#   'fund2invest': {'invetsment sector': '4%',
#    'tourism and hospitality': '8%',
#    'animal husbandary': '7%',
#    'infrastructure': '8%',
#    'cottage industries': '1%',
#    'personal service business': '7%',
#    'retail business': '5%',
#    'consultancy service': '2%',
#    'alternative energy': '5%',
#    'agriculture': '7%',
#    'total_fund': 9391},
#   'remittance': [{'month': 9, 'amount': 370},
#    {'month': 2, 'amount': 599},
#    {'month': 3, 'amount': 205},
#    {'month': 11, 'amount': 807},
#    {'month': 12, 'amount': 820},
#    {'month': 2, 'amount': 290}],
#   'travell': [{'date': '2017.4.24',
#     'place': {'country': 'Vietnam', 'city': 'A'}},
#    {'date': '2019.5.4', 'place': {'country': 'Mozambique', 'city': 'MAPUTO'}},
#    {'date': '2019.12.18',
#     'place': {'country': 'Guadeloupe', 'city': 'BASSE-TERRE'}},
#    {'date': '2017.1.10', 'place': {'country': 'New-Caledonia', 'city': 'A'}},
#    {'date': '2012.10.15',
#     'place': {'country': 'Myanmar-[Burma]', 'city': 'N'}}],
#   'social_work': [{'date': '2014.2.19', 'work': 'fitness programme'},
#    {'date': '2003.12.27', 'work': 'voice against corruption'},
#    {'date': '2011.1.28', 'work': 'building temples'},
#    {'date': '2014.4.1', 'work': 'poverty elimination'},
#    {'date': '2013.7.18', 'work': 'pollution control'}],
#   'personal_view': ['A day after the Panama Papers were exposed in April 2016, the Department of Money Laundering Investigation promised it would ‘begin a probe’ after calling a meeting of key stakeholders including the Financial Information Unit of Nepal Rastra Bank, the Department of Revenue Investigation and the Nepal Police. Following the meeting, the head of the Department of Money Laundering Investigation promised to adopt a ‘risk-based supervision system’ and claimed that the Financial Information Unit and the Central Investigation Bureau of the Nepal Police would ‘conduct an investigation’. As recent revelations have indicated, the investigations reaped minimal results in the last two years.']},
#  {'ID': '66C9X10E0M',
#   'age': 29,
#   'gender': 'male',
#   'profession': {'major': 'Farming, Fishing, and Forestry Occupations',
#    'branch': 'Agricultural Inspectors'},
#   'interest': 'travel',
#   'home_address': {'province': 'PN7',
#    'district': 'Doti',
#    'MCP': 'K.I Singh RM',
#    'ward': 'Ward 2'},
#   'foreign_address': {'country': 'Venezuela',
#    'ID': 'VE',
#    'lat': '6.42375',
#    'lon': '-66.58973',
#    'city': 'A'},
#   'date_out': '2019.10.28',
#   'date_return': '2019.5.15',
#   'fund2invest': {'invetsment sector': '7%',
#    'tourism and hospitality': '2%',
#    'animal husbandary': '8%',
#    'infrastructure': '1%',
#    'cottage industries': '3%',
#    'personal service business': '4%',
#    'retail business': '1%',
#    'consultancy service': '6%',
#    'alternative energy': '5%',
#    'agriculture': '10%',
#    'total_fund': 7654},
#   'remittance': [{'month': 8, 'amount': 140},
#    {'month': 5, 'amount': 864},
#    {'month': 9, 'amount': 113},
#    {'month': 5, 'amount': 232},
#    {'month': 1, 'amount': 348}],
#   'travell': [{'date': '2016.7.20',
#     'place': {'country': 'Georgia', 'city': 'TBILISI'}},
#    {'date': '2015.3.3', 'place': {'country': 'Uzbekistan', 'city': 'Karshi'}}],
#   'social_work': [{'date': '2004.4.6', 'work': 'culture saving programme'},
#    {'date': '2018.5.16', 'work': 'security plan'},
#    {'date': '2015.10.9', 'work': 'voice against racism'},
#    {'date': '2007.7.14', 'work': 'drinking water management'}],
#   'personal_view': ['Around 30 years, over a dozen missed deadlines, and two terminated contracts since it was first announced, the Melamchi Water Supply Project hangs in limbo, once again. Following months of conflict with the Italian contractor Cooperativa Muratori e Cementisti di Ravenna (CMC), the government has now formally issued a letter of termination, causing further (and seemingly perpetual) delays to the national pride project. Granted, delays to the project stopped surprising people 20 years and over a dozen-missed deadlines ago, but the current fiasco warrants introspection, especially as officials claim that the project is only 5 percent shy of completion.']},
#  {'ID': '7A6VKHNE9Q',
#   'age': 42,
#   'gender': 'female',
#   'profession': {'major': 'Architecture and Engineering Occupations',
#    'branch': 'Cartographers and Photogrammetrists'},
#   'interest': 'singing',
#   'home_address': {'province': 'PN6',
#    'district': 'Jumla',
#    'MCP': 'Guthichaur RM',
#    'ward': 'Ward 4'},
#   'foreign_address': {'country': 'Swaziland',
#    'ID': 'SZ',
#    'lat': '-26.522503',
#    'lon': '31.465866',
#    'city': 'A'},
#   'date_out': '2016.7.28',
#   'date_return': '2024.10.23',
#   'fund2invest': {'invetsment sector': '1%',
#    'tourism and hospitality': '10%',
#    'animal husbandary': '3%',
#    'infrastructure': '1%',
#    'cottage industries': '4%',
#    'personal service business': '6%',
#    'retail business': '9%',
#    'consultancy service': '9%',
#    'alternative energy': '10%',
#    'agriculture': '8%',
#    'total_fund': 4116},
#   'remittance': [{'month': 5, 'amount': 429},
#    {'month': 4, 'amount': 259},
#    {'month': 4, 'amount': 782},
#    {'month': 1, 'amount': 387}],
#   'travell': [{'date': '2013.10.27',
#     'place': {'country': 'Thailand', 'city': 'Phatthalung'}},
#    {'date': '2019.5.12', 'place': {'country': 'Vatican-City', 'city': 'N'}},
#    {'date': '2018.5.29',
#     'place': {'country': 'Panama', 'city': 'San Miguelito'}}],
#   'social_work': [{'date': '2018.2.29', 'work': 'community sanitation'},
#    {'date': '2012.4.6', 'work': 'resolving the conflict'},
#    {'date': '2008.12.23', 'work': 'helping the homeless'},
#    {'date': '2006.3.20', 'work': 'medical camp'},
#    {'date': '2004.7.21', 'work': 'trust for welfare'}],
#   'personal_view': ['The move to shut down these services outright without much deliberation between stakeholder groups is a disservice to commuters and entrepreneurs. Tootle and Pathao are popular services that have made the lives of capital residents much easier by providing a middle-ground option for commuters: more comfortable than public transportation and more affordable than taxis. It is much easier to get in touch with a rider using an app on their phone, hop in, and get to the destination relatively faster and at a much cheaper rate. At the same time, these ride-hailing services are providing employment opportunities to many in the city.']},
#  {'ID': 'K8P0CX2V99',
#   'age': 34,
#   'gender': 'female',
#   'profession': {'major': 'Sales and Related Occupations',
#    'branch': 'Travel Agents'},
#   'interest': 'business',
#   'home_address': {'province': 'PN6',
#    'district': 'Dailekh',
#    'MCP': 'Bairavi RM',
#    'ward': 'Ward 4'},
#   'foreign_address': {'country': 'Antarctica',
#    'ID': 'AQ',
#    'lat': '-75.250973',
#    'lon': '-0.071389',
#    'city': 'N'},
#   'date_out': '2019.7.20',
#   'date_return': '2025.3.26',
#   'fund2invest': {'invetsment sector': '5%',
#    'tourism and hospitality': '8%',
#    'animal husbandary': '1%',
#    'infrastructure': '2%',
#    'cottage industries': '7%',
#    'personal service business': '3%',
#    'retail business': '4%',
#    'consultancy service': '2%',
#    'alternative energy': '7%',
#    'agriculture': '1%',
#    'total_fund': 2469},
#   'remittance': [{'month': 1, 'amount': 937},
#    {'month': 10, 'amount': 736},
#    {'month': 11, 'amount': 189},
#    {'month': 10, 'amount': 351}],
#   'travell': [{'date': '2019.4.30',
#     'place': {'country': 'Singapore', 'city': 'SINGAPORE'}},
#    {'date': '2018.3.3', 'place': {'country': 'Belarus', 'city': 'Vitebsk'}}],
#   'social_work': [{'date': '2010.2.8', 'work': 'drinking water management'},
#    {'date': '2015.2.24', 'work': 'poverty elimination'},
#    {'date': '2010.1.20', 'work': 'creating employment'},
#    {'date': '2010.12.25', 'work': 'donation for school'}],
#   'personal_view': ['While all parties involved in the construction process have contributed to the current fiasco, one lesson is especially poignant as stakeholders take the next necessary steps to identify a new contractor: more thoughtful deliberation must factor into procurement decisions. A number of factors—including corruption, mismanagement, deviation from contract promises, sluggish cash flow, and a circular bout of finger pointing—has played into the current Melamchi saga. But tussles between contractors and government officials, often manifesting in contract terminations, have featured heavily in these delays.']},
#  {'ID': '9ZMLWRZO17',
#   'age': 36,
#   'gender': 'female',
#   'profession': {'major': 'Life, Physical, and Social Science Occupations',
#    'branch': 'Geographers'},
#   'interest': 'poem',
#   'home_address': {'province': 'PN5',
#    'district': 'Eastern_Rukum',
#    'MCP': 'Bhume RM',
#    'ward': 'Ward 4'},
#   'foreign_address': {'country': 'United-Arab-Emirates',
#    'ID': 'AE',
#    'lat': '23.424076',
#    'lon': '53.847818',
#    'city': 'N'},
#   'date_out': '2018.1.2',
#   'date_return': '2022.6.22',
#   'fund2invest': {'invetsment sector': '1%',
#    'tourism and hospitality': '7%',
#    'animal husbandary': '1%',
#    'infrastructure': '9%',
#    'cottage industries': '9%',
#    'personal service business': '1%',
#    'retail business': '4%',
#    'consultancy service': '8%',
#    'alternative energy': '9%',
#    'agriculture': '4%',
#    'total_fund': 2669},
#   'remittance': [{'month': 6, 'amount': 737},
#    {'month': 8, 'amount': 203},
#    {'month': 8, 'amount': 791},
#    {'month': 9, 'amount': 745},
#    {'month': 10, 'amount': 689}],
#   'travell': [{'date': '2018.2.13',
#     'place': {'country': 'Bhutan', 'city': 'THIMPHU'}},
#    {'date': '2019.10.23',
#     'place': {'country': 'Latvia', 'city': 'Daugavpils'}},
#    {'date': '2017.3.7', 'place': {'country': 'France', 'city': 'Nice'}},
#    {'date': '2011.3.5',
#     'place': {'country': 'U.S.-Virgin-Islands', 'city': 'N'}}],
#   'social_work': [{'date': '2008.12.17',
#     'work': 'society development project'},
#    {'date': '2010.6.11', 'work': 'medical camp'},
#    {'date': '2008.6.28', 'work': 'social act on awareness'},
#    {'date': '2015.6.2', 'work': 'workshop for young'},
#    {'date': '2012.10.12', 'work': 'resettlement for groups'}],
#   'personal_view': ['When the Centre for Investigative Journalism-Nepal released its report revealing how over 50 Nepalis exploited secretive tax regimes and broke the country’s law by investing in different offshore companies, sections of the public eagerly anticipated a swift and stringent response from the government. And when the Prime Minister’s Office directed the Financial Information Unit under Nepal Rastra Bank to expedite ‘a probe into businesses and businesspeople’ last week, those steps appeared to be making ground—at least upon cursory examination. The promise of a ‘serious probe’ devoid of any comprehensive strategy is not only wholly inadequate but also frustratingly familiar.An almost parallel call was made three years ago, when the Panama Papers, leaked by the International Consortium of Investigative Journalists, revealed the names of more than 20 Nepalis parking their wealth in a number of tax haven countries and territories.']},
#  {'ID': 'JQPP89162S',
#   'age': 25,
#   'gender': 'male',
#   'profession': {'major': 'Architecture and Engineering Occupations',
#    'branch': 'Environmental Engineering Technologists and Technicians'},
#   'interest': 'poem',
#   'home_address': {'province': 'PN4',
#    'district': 'Lamjung',
#    'MCP': 'Dhudh Pokhari RM',
#    'ward': 'Ward 3'},
#   'foreign_address': {'country': 'Greece',
#    'ID': 'GR',
#    'lat': '39.074208',
#    'lon': '21.824312',
#    'city': 'Iraclion'},
#   'date_out': '2014.1.29',
#   'date_return': '2022.8.30',
#   'fund2invest': {'invetsment sector': '4%',
#    'tourism and hospitality': '9%',
#    'animal husbandary': '2%',
#    'infrastructure': '8%',
#    'cottage industries': '1%',
#    'personal service business': '5%',
#    'retail business': '6%',
#    'consultancy service': '8%',
#    'alternative energy': '9%',
#    'agriculture': '3%',
#    'total_fund': 8629},
#   'remittance': [{'month': 3, 'amount': 881},
#    {'month': 5, 'amount': 737},
#    {'month': 4, 'amount': 827}],
#   'travell': [{'date': '2015.9.27',
#     'place': {'country': 'Ireland', 'city': 'Cork'}},
#    {'date': '2010.3.12', 'place': {'country': 'Uganda', 'city': 'Mbarara'}},
#    {'date': '2010.6.5', 'place': {'country': 'Burundi', 'city': 'BUJUMBURA'}},
#    {'date': '2011.1.26', 'place': {'country': 'Cape-Verde', 'city': 'A'}},
#    {'date': '2010.6.29',
#     'place': {'country': 'Netherlands-Antilles', 'city': 'N'}}],
#   'social_work': [{'date': '2018.8.7', 'work': 'small industries for women'},
#    {'date': '2012.1.27', 'work': 'culture saving programme'},
#    {'date': '2017.10.13', 'work': 'solid waste management'},
#    {'date': '2012.6.23', 'work': 'donation for school'},
#    {'date': '2010.7.12', 'work': 'skill development training'}],
#   'personal_view': ['In response to the pressure, Parliament devised several legislative measures to monitor money laundering—including the endorsement of the Anti-Money Laundering Act and the establishment of the Department of Money Laundering Investigation in 2011. After being removed from the FATF’s watch list in June 2011, the government seemingly forgot about its commitment to the cause. In the seven years of existence, the Department of Money Laundering Investigation has filed a meagre 40 money laundering cases at the Special Court, and most of them against petty or more low-profile violators. In the past three years, only 10 cases were filed, most of them related to minor charges. This points to a dismal conclusion: Issues related to money laundering only seem to matter when global monitoring organisations intervene']},
#  {'ID': 'QP373XQ6S3',
#   'age': 43,
#   'gender': 'male',
#   'profession': {'major': 'Transportation and Material Moving Occupations',
#    'branch': 'Automotive and Watercraft Service Attendants'},
#   'interest': 'teaching',
#   'home_address': {'province': 'PN4',
#    'district': 'Mustang',
#    'MCP': 'Lomanthang RM',
#    'ward': 'Ward 2'},
#   'foreign_address': {'country': 'Chad',
#    'ID': 'TD',
#    'lat': '15.454166',
#    'lon': '18.732207',
#    'city': "N'DJAMENA"},
#   'date_out': '2011.7.3',
#   'date_return': '2025.12.4',
#   'fund2invest': {'invetsment sector': '8%',
#    'tourism and hospitality': '5%',
#    'animal husbandary': '7%',
#    'infrastructure': '3%',
#    'cottage industries': '10%',
#    'personal service business': '3%',
#    'retail business': '1%',
#    'consultancy service': '7%',
#    'alternative energy': '7%',
#    'agriculture': '10%',
#    'total_fund': 2986},
#   'remittance': [{'month': 11, 'amount': 571},
#    {'month': 6, 'amount': 292},
#    {'month': 6, 'amount': 116},
#    {'month': 3, 'amount': 766},
#    {'month': 2, 'amount': 831}],
#   'travell': [{'date': '2012.7.19',
#     'place': {'country': 'São-Tomé-and-Príncipe', 'city': 'N'}},
#    {'date': '2019.8.18', 'place': {'country': 'Palau', 'city': 'KOROR'}},
#    {'date': '2016.2.3',
#     'place': {'country': 'Senegal', 'city': 'Guediawaye'}}],
#   'social_work': [{'date': '2007.3.23', 'work': 'building temples'},
#    {'date': '2013.9.21', 'work': 'fitness programme'},
#    {'date': '2017.6.26', 'work': 'culture saving programme'},
#    {'date': '2010.5.8', 'work': 'security plan'}],
#   'personal_view': ['Yet, having said that, the companies cannot operate without taking responsibility for their actions. The terms and services page of both Tootle and Pathao mention that they are only ‘a technology company that does not provide or engage in transportation services’. It further mentions that ‘the company is not a transportation provider’. These statements make it easier for them to shirk responsibility. Also, it does not make them liable for the insurance of the rider or the passenger in case of an accident. As a service provider, ensuring the safety of customers should be any company’s top priority—especially in the business of transportation.']},
#  {'ID': 'V4TI4Q471M',
#   'age': 47,
#   'gender': 'male',
#   'profession': {'major': 'Transportation and Material Moving Occupations',
#    'branch': 'Rail Transportation Workers, All Other'},
#   'interest': 'literature',
#   'home_address': {'province': 'PN7',
#    'district': 'Kailali',
#    'MCP': 'Godavari MCP',
#    'ward': 'Ward 1'},
#   'foreign_address': {'country': 'Isle-of-Man',
#    'ID': 'IM',
#    'lat': '54.236107',
#    'lon': '-4.548056',
#    'city': 'N'},
#   'date_out': '2017.4.29',
#   'date_return': '2023.2.14',
#   'fund2invest': {'invetsment sector': '2%',
#    'tourism and hospitality': '5%',
#    'animal husbandary': '7%',
#    'infrastructure': '7%',
#    'cottage industries': '7%',
#    'personal service business': '5%',
#    'retail business': '10%',
#    'consultancy service': '8%',
#    'alternative energy': '9%',
#    'agriculture': '2%',
#    'total_fund': 6632},
#   'remittance': [{'month': 9, 'amount': 576},
#    {'month': 1, 'amount': 637},
#    {'month': 10, 'amount': 388}],
#   'travell': [{'date': '2015.1.30',
#     'place': {'country': 'Estonia', 'city': 'TALLINN'}},
#    {'date': '2016.7.7', 'place': {'country': 'Paraguay', 'city': 'Luque'}},
#    {'date': '2018.8.22', 'place': {'country': 'Kazakhstan', 'city': 'Atirau'}},
#    {'date': '2011.6.20',
#     'place': {'country': 'Solomon-Islands', 'city': 'A'}}],
#   'social_work': [{'date': '2015.7.27',
#     'work': 'awareness programme for maternal women'},
#    {'date': '2008.10.13', 'work': 'solid waste management'},
#    {'date': '2014.10.12', 'work': 'workshop for young'},
#    {'date': '2016.12.13', 'work': 'resolving the conflict'}],
#   'personal_view': ['Yet, having said that, the companies cannot operate without taking responsibility for their actions. The terms and services page of both Tootle and Pathao mention that they are only ‘a technology company that does not provide or engage in transportation services’. It further mentions that ‘the company is not a transportation provider’. These statements make it easier for them to shirk responsibility. Also, it does not make them liable for the insurance of the rider or the passenger in case of an accident. As a service provider, ensuring the safety of customers should be any company’s top priority—especially in the business of transportation.']},
#  {'ID': 'IEWHWW4MV6',
#   'age': 37,
#   'gender': 'male',
#   'profession': {'major': 'Business and Financial Operations Occupations',
#    'branch': 'Financial Analysts and Advisors'},
#   'interest': 'travel',
#   'home_address': {'province': 'PN2',
#    'district': 'Rautahat',
#    'MCP': 'Phatuwa Bijayapur RM',
#    'ward': 'Ward 5'},
#   'foreign_address': {'country': 'Mauritius',
#    'ID': 'MU',
#    'lat': '-20.348404',
#    'lon': '57.552152',
#    'city': 'Vacoas - Phoenix'},
#   'date_out': '2014.1.12',
#   'date_return': '2023.8.1',
#   'fund2invest': {'invetsment sector': '10%',
#    'tourism and hospitality': '7%',
#    'animal husbandary': '9%',
#    'infrastructure': '2%',
#    'cottage industries': '3%',
#    'personal service business': '5%',
#    'retail business': '7%',
#    'consultancy service': '10%',
#    'alternative energy': '1%',
#    'agriculture': '5%',
#    'total_fund': 8255},
#   'remittance': [{'month': 9, 'amount': 712},
#    {'month': 2, 'amount': 518},
#    {'month': 6, 'amount': 707},
#    {'month': 3, 'amount': 960},
#    {'month': 3, 'amount': 769},
#    {'month': 6, 'amount': 904}],
#   'travell': [{'date': '2016.3.3',
#     'place': {'country': 'Lithuania', 'city': 'Shauliai'}},
#    {'date': '2014.3.12',
#     'place': {'country': 'Slovenia', 'city': 'LJUBLJANA'}},
#    {'date': '2018.3.23', 'place': {'country': 'Sweden', 'city': 'Linköping'}}],
#   'social_work': [{'date': '2001.6.22', 'work': 'community forest'},
#    {'date': '2011.1.13', 'work': 'fitness programme'},
#    {'date': '2014.4.2', 'work': 'rahabilitation programme'}],
#   'personal_view': ['Yet, having said that, the companies cannot operate without taking responsibility for their actions. The terms and services page of both Tootle and Pathao mention that they are only ‘a technology company that does not provide or engage in transportation services’. It further mentions that ‘the company is not a transportation provider’. These statements make it easier for them to shirk responsibility. Also, it does not make them liable for the insurance of the rider or the passenger in case of an accident. As a service provider, ensuring the safety of customers should be any company’s top priority—especially in the business of transportation.']}]

# %%
with open("sample.json","w")as fw:
    json.dump(Data,fw)
